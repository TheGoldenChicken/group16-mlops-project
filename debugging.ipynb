# %%
from tests.test_dataset_preprocessor import test_data_preprocessor
from tests.test_model import test_model

# %%
test_data_preprocessor()

test_model()

# %%
from datasets import load_dataset

dataset = load_dataset("fashion_mnist")

# %%
from fmnist.predict_model import predict_endpoint
import torch
import matplotlib.pyplot as plt

test_dataset = torch.load("data/processed/test.pt")
sample = test_dataset[0]
test_image = sample[0].unsqueeze(0)

# show image
plt.imshow(test_image.squeeze(0), cmap="gray")
plt.show()

# Save test image
torch.save(test_image, "data/processed/test_image.pt")
